# %% [markdown]
# Q. what is amazon sagemaker python sdk?<br>
# A. you build, train, and deploy ML models with python code from a jupyter notebook.
#
#
# Q. how to get to the documentation of models that you can use in sagemaker?<br>
# aws sagemaker documentation: [link](https://docs.aws.amazon.com/sagemaker/latest/dg/k-nearest-neighbors.html)<br>
# you can use the sample notebooks as a good example for how to use the ml model (estimator). [link for knn sample notebook](https://sagemaker-examples.readthedocs.io/en/latest/introduction_to_amazon_algorithms/k_nearest_neighbors_covtype/k_nearest_neighbors_covtype.html)

# %%
import boto3

# %%
import sagemaker

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset('penguins')
print(f'penguins.shape: {penguins.shape}')
# Out:
# penguins.shape: (344, 7)

# %%
penguins['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
num_map = {'Adelie':0, 'Chinstrap':1, 'Gentoo':2}

# %%
penguins['species'] = penguins['species'].map(num_map)

# %%
penguins = penguins.dropna()
print(f'penguins.shape: {penguins.shape}')
# Out:
# penguins.shape: (333, 7)

# %%
import pandas as pd

# %%
penguins = pd.get_dummies(penguins,drop_first=True)
print(f'penguins.shape: {penguins.shape}')
# Out:
# penguins.shape: (333, 8)

# %%
penguins
# Out:
#      species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0          0            39.1           18.7              181.0       3750.0
# 1          0            39.5           17.4              186.0       3800.0
# 2          0            40.3           18.0              195.0       3250.0
# 4          0            36.7           19.3              193.0       3450.0
# 5          0            39.3           20.6              190.0       3650.0
# ..       ...             ...            ...                ...          ...
# 338        2            47.2           13.7              214.0       4925.0
# 340        2            46.8           14.3              215.0       4850.0
# 341        2            50.4           15.7              222.0       5750.0
# 342        2            45.2           14.8              212.0       5200.0
# 343        2            49.9           16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_Male
# 0           False              True      True
# 1           False              True     False
# 2           False              True     False
# 4           False              True     False
# 5           False              True      True
# ..            ...               ...       ...
# 338         False             False     False
# 340         False             False     False
# 341         False             False      True
# 342         False             False     False
# 343         False             False      True
#
# [333 rows x 8 columns]

# %%
train_data = penguins.sample(frac=0.8)
print(f'train_data.shape: {train_data.shape}')
train_data.head(2)
# Out:
# train_data.shape: (266, 8)
#      species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 241        2            45.1           14.5              215.0       5000.0
# 196        1            50.9           17.9              196.0       3675.0
#
#      island_Dream  island_Torgersen  sex_Male
# 241         False             False     False
# 196          True             False     False

# %%
# train_data

# %%
test_data = penguins.drop(train_data.index)
print(f'test_data.shape: {test_data.shape}')
test_data.head(2)
# Out:
# test_data.shape: (67, 8)
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 4         0            36.7           19.3              193.0       3450.0
# 16        0            38.7           19.0              195.0       3450.0
#
#     island_Dream  island_Torgersen  sex_Male
# 4          False              True     False
# 16         False              True     False

# %%
# test_data

# %%
import boto3

# %%
bucket_name = 'penguins-example-bucket-course'

# %%
s3 = boto3.client('s3')

# %%
s3.create_bucket(Bucket=bucket_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'QNDMSCJ7P2CG5XSN',
#   'HostId': 'Wm+PD1EG929R65RL7eGrcOfFY30OMpmpF5W74I12E0WfPv5e2er9p1KMRvc5fsMQ1ymI0CDzmS4=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'Wm+PD1EG929R65RL7eGrcOfFY30OMpmpF5W74I12E0WfPv5e2er9p1KMRvc5fsMQ1ymI0CDzmS4=',
#    'x-amz-request-id': 'QNDMSCJ7P2CG5XSN',
#    'date': 'Thu, 11 Apr 2024 21:29:38 GMT',
#    'location': '/penguins-example-bucket-course',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': '/penguins-example-bucket-course'}

# %% [markdown]
# 1. create folders inside the s3 bucket

# %%
prefixes = ['test/', 'train/', 'output/']

# %%
for prefix in prefixes:
    s3.put_object(Bucket=bucket_name,Key=prefix)

# %% [markdown]
# 2. save train and test files locally

# %%
train_data.to_csv('penguins_train.csv',index=False,header=False)

# %%
test_data.to_csv('penguins_test.csv',index=False,header=False)

# %%
train_file_name = 'penguins_train.csv'
test_file_name = 'penguins_test.csv'

# %% [markdown]
# 3. upload local csv files to s3 buckets

# %%
s3.upload_file(train_file_name, bucket_name, 'train/penguins_train.csv')

# %%
s3.upload_file(test_file_name,bucket_name,'test/penguins_test.csv')

# %%
import sagemaker

# %% [markdown]
# 4. create training data input definition for an Amazon SageMaker training job

# %%
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://penguins-example-bucket-course/train/penguins_train.csv',
                                                content_type='text/csv')

# %% [markdown]
# 5. create test data input definition for an Amazon SageMaker test job

# %%
s3_input_test = sagemaker.inputs.TrainingInput(s3_data='s3://penguins-example-bucket-course/test/penguins_test.csv',
                                                content_type='text/csv')

# %%
from sagemaker import get_execution_role
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from sagemaker import get_execution_role
#
# ImportError: cannot import name 'get_execution_role' from 'sagemaker' (/home/alin/miniconda3/envs/py12/lib/python3.12/site-packages/sagemaker/__init__.py)

# %%
get_execution_role()
# Out:
# 'arn:aws:iam::472948420345:role/service-role/AmazonSageMaker-ExecutionRole-20240304T111312'

# %% [markdown]
# 6. setup your estimator (ml model) from amazon sagemaker

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 from sagemaker.amazon.amazon_estimator import get_image_uri
#
# ModuleNotFoundError: No module named 'sagemaker.amazon'

# %% [markdown]
# 6.1. get location (uri) of the image of your estimator<br>
# In Amazon SageMaker, “Amazon estimators” usually refers to the built-in algorithms provided and maintained by AWS. These are delivered as Docker images, which is why you retrieve them via get_image_uri (or the newer image_uris.retrieve).<br>
# `image_uri` is the location to the image of your estimators.

# %%
knn_uri = get_image_uri(boto3.Session().region_name,'knn')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# 6.2. create your estimator object<br>
# `output_path`: location where s3 stores the trained model after you fit the model to the training data.

# %%
knn_model = sagemaker.estimator.Estimator(image_uri=knn_uri,
                                          role=get_execution_role(),
                                          instance_count=1,
                                          instance_type='ml.m5.2xlarge',
                                          output_path='s3://penguins-example-bucket-course/output/', 
                                          sagemaker_session=sagemaker.Session()
                                         )

# %% [markdown]
# 6.3. set the model hyper-parameters

# %%
knn_model.set_hyperparameters(k=3, sample_size=333, predictor_type='classifier')

# %% [markdown]
# 6.4. fit the knn model to training data

# %% [markdown]
# Q. what happens when you fit your knn_model?<br>
# A. <br>
# - Trains the model
# - Packages the trained model into model.tar.gz
# - Uploads it to the S3 path specified by output_path
#
# ```python
# Example S3 location:
# s3://penguins-example-bucket-course/output/<training-job-name>/output/model.tar.gz
# ```
#
# ----

# %% [markdown]
# Q. what is this model artifacts (`model.tar.gz`)?<br>
# A. model.tar.gz is the entire trained model package, not just the raw weights.<br>
# It contains everything needed for inference by the container, except the container image itself.
#
# Q. if it has everything for inference and it has everything from the model, why does it need ontainer image itself?<br>
# A. `model.tar.gz` has the model, but not the runtime environment.<br>
#
# ##### `model.tar.gz` = WHAT to run
#
# -   Model weights
# -   Model structure
# -   Inference code
# -   Preprocessing artifacts
#
# ##### Container image = HOW to run it
#
# -   Operating system
# -   Python runtime
# -   ML framework (PyTorch / TensorFlow / XGBoost / scikit-learn)
# -   System libraries (CUDA, BLAS, etc.)
# -   SageMaker serving logic (HTTP server, batch worker)
#
# Both are required.
#
# ----

# %% [markdown]
# Q. how to later retrieve the trained model?<br>
# A. <br>
# ```python
# from sagemaker.model import Model
# from sagemaker import get_execution_role
#
# knn_loaded_model = Model(
#     image_uri=knn_uri,
#     model_data='s3://penguins-example-bucket-course/output/<job-name>/output/model.tar.gz',
#     role=get_execution_role(),
#     sagemaker_session=sagemaker.Session()
# )
# ```
#
# ----

# %%
knn_model.fit({'train':s3_input_train, 'validation':s3_input_test})
# Out:
# INFO:sagemaker:Creating training-job with name: knn-2024-04-11-22-57-04-683
# 2024-04-11 22:57:04 Starting - Starting the training job...
# 2024-04-11 22:57:20 Starting - Preparing the instances for training...
# 2024-04-11 22:58:02 Downloading - Downloading the training image........................
# 2024-04-11 23:01:48 Training - Training image download completed. Training in progress...Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/11/2024 23:02:15 INFO 139721676150592] Reading default configuration from /opt/amazon/lib/python3.9/site-packages/algorithm/resources/default-conf.json: {'_kvstore': 'dist_async', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_tuning_objective_metric': '', '_faiss_index_nprobe': '5', 'epochs': '1', 'feature_dim': 'auto', 'faiss_index_ivf_nlists': 'auto', 'index_metric': 'L2', 'index_type': 'faiss.Flat', 'mini_batch_size': '5000', '_enable_profiler': 'false'}
# [04/11/2024 23:02:15 INFO 139721676150592] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'k': '3', 'predictor_type': 'classifier', 'sample_size': '333'}
# [04/11/2024 23:02:15 INFO 139721676150592] Final configuration: {'_kvstore': 'dist_async', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_tuning_objective_metric': '', '_faiss_index_nprobe': '5', 'epochs': '1', 'feature_dim': 'auto', 'faiss_index_ivf_nlists': 'auto', 'index_metric': 'L2', 'index_type': 'faiss.Flat', 'mini_batch_size': '5000', '_enable_profiler': 'false', 'k': '3', 'predictor_type': 'classifier', 'sample_size': '333'}
# /opt/amazon/lib/python3.9/site-packages/scipy/optimize/_shgo.py:495: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if cons['type'] is 'ineq':
# /opt/amazon/lib/python3.9/site-packages/scipy/optimize/_shgo.py:743: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if len(self.X_min) is not 0:
# [04/11/2024 23:02:19 WARNING 139721676150592] Loggers have already been setup.
# [04/11/2024 23:02:19 INFO 139721676150592] Final configuration: {'_kvstore': 'dist_async', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_tuning_objective_metric': '', '_faiss_index_nprobe': '5', 'epochs': '1', 'feature_dim': 'auto', 'faiss_index_ivf_nlists': 'auto', 'index_metric': 'L2', 'index_type': 'faiss.Flat', 'mini_batch_size': '5000', '_enable_profiler': 'false', 'k': '3', 'predictor_type': 'classifier', 'sample_size': '333'}
# [04/11/2024 23:02:19 WARNING 139721676150592] Loggers have already been setup.
# [04/11/2024 23:02:19 INFO 139721676150592] Launching parameter server for role scheduler
# [04/11/2024 23:02:19 INFO 139721676150592] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-72-43.ec2.internal', 'TRAINING_JOB_NAME': 'knn-2024-04-11-22-57-04-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:472948420345:training-job/knn-2024-04-11-22-57-04-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-9e31ebd33ae88ec1ac1988314b3b6642ca4f8d2a13afc92d2ea3df4a8638e230-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.9/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '4', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [04/11/2024 23:02:19 INFO 139721676150592] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-72-43.ec2.internal', 'TRAINING_JOB_NAME': 'knn-2024-04-11-22-57-04-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:472948420345:training-job/knn-2024-04-11-22-57-04-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-9e31ebd33ae88ec1ac1988314b3b6642ca4f8d2a13afc92d2ea3df4a8638e230-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.9/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '4', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.72.43', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [04/11/2024 23:02:19 INFO 139721676150592] Launching parameter server for role server
# [04/11/2024 23:02:19 INFO 139721676150592] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-72-43.ec2.internal', 'TRAINING_JOB_NAME': 'knn-2024-04-11-22-57-04-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:472948420345:training-job/knn-2024-04-11-22-57-04-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-9e31ebd33ae88ec1ac1988314b3b6642ca4f8d2a13afc92d2ea3df4a8638e230-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.9/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '4', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [04/11/2024 23:02:19 INFO 139721676150592] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-72-43.ec2.internal', 'TRAINING_JOB_NAME': 'knn-2024-04-11-22-57-04-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:472948420345:training-job/knn-2024-04-11-22-57-04-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-9e31ebd33ae88ec1ac1988314b3b6642ca4f8d2a13afc92d2ea3df4a8638e230-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.9/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '4', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.72.43', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [04/11/2024 23:02:19 INFO 139721676150592] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-72-43.ec2.internal', 'TRAINING_JOB_NAME': 'knn-2024-04-11-22-57-04-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:472948420345:training-job/knn-2024-04-11-22-57-04-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-9e31ebd33ae88ec1ac1988314b3b6642ca4f8d2a13afc92d2ea3df4a8638e230-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.9/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '4', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.72.43', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 38 is a shell:scheduler.
# Process 47 is a shell:server.
# Process 7 is a worker.
# [04/11/2024 23:02:19 INFO 139721676150592] Using default worker.
# [04/11/2024 23:02:19 INFO 139721676150592] Loading faiss with AVX2 support.
# [04/11/2024 23:02:19 INFO 139721676150592] Successfully loaded faiss with AVX2 support.
# [04/11/2024 23:02:19 INFO 139721676150592] Checkpoint loading and saving are disabled.
# /opt/amazon/python3.9/lib/python3.9/subprocess.py:941: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [04/11/2024 23:02:19 INFO 139721676150592] nvidia-smi: took 0.107 seconds to run.
# [04/11/2024 23:02:19 INFO 139721676150592] nvidia-smi identified 0 GPUs.
# [04/11/2024 23:02:19 ERROR 139721676150592] nvidia-smi: failed to run (127): b'/bin/sh: nvidia-smi: command not found'/
# [04/11/2024 23:02:19 WARNING 139721676150592] Could not determine free memory in MB for GPU device with ID (0).
# [04/11/2024 23:02:19 INFO 139721676150592] Using per-machine sample size = 333 (Available virtual memory = 31056486400 bytes, GPU free memory = 0 bytes, number of machines = 1). If an out-of-memory error occurs, choose a larger instance type, use dimension reduction, decrease sample_size, increase the number of instances, and/or decrease mini_batch_size.
# #metrics {"StartTime": 1712876539.8544729, "EndTime": 1712876539.8545132, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [04/11/2024 23:02:19 INFO 139721676150592] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1712876539.8548281, "EndTime": 1712876539.8639133, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 266.0, "count": 1, "min": 266, "max": 266}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 266.0, "count": 1, "min": 266, "max": 266}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 266.0, "count": 1, "min": 266, "max": 266}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [04/11/2024 23:02:19 INFO 139721676150592] #throughput_metric: host=algo-1, train throughput=28954.76134122288 records/second
# [04/11/2024 23:02:19 INFO 139721676150592] Create Store: dist_async
# [23:02:19] ../src/base.cc:47: Please install cuda driver for GPU use.  No cuda driver detected.
# [23:02:20] ../src/base.cc:47: Please install cuda driver for GPU use.  No cuda driver detected.
# [23:02:20] ../src/base.cc:47: Please install cuda driver for GPU use.  No cuda driver detected.
# [04/11/2024 23:02:20 INFO 139721676150592] Using in-memory reservoir sample from master machine...
# [04/11/2024 23:02:20 INFO 139721676150592] ...Got reservoir sample from algo-1: data=(266, 7), labels=(266,), NaNs=0
# [04/11/2024 23:02:20 INFO 139721676150592] Training index...
# [04/11/2024 23:02:20 INFO 139721676150592] ...Finished training index in 0 second(s)
# [04/11/2024 23:02:20 INFO 139721676150592] Adding data to index...
# [04/11/2024 23:02:20 INFO 139721676150592] ...Finished adding data to index in 0 second(s)
# #metrics {"StartTime": 1712876539.7038748, "EndTime": 1712876540.7889953, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 140.10095596313477, "count": 1, "min": 140.10095596313477, "max": 140.10095596313477}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 8.88967514038086, "count": 1, "min": 8.88967514038086, "max": 8.88967514038086}, "finalize.time": {"sum": 1.7960071563720703, "count": 1, "min": 1.7960071563720703, "max": 1.7960071563720703}, "model.serialize.time": {"sum": 5.029439926147461, "count": 1, "min": 5.029439926147461, "max": 5.029439926147461}}}
# [04/11/2024 23:02:20 INFO 139721676150592] Test data is not provided.
# #metrics {"StartTime": 1712876540.789082, "EndTime": 1712876540.7892203, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 15.233516693115234, "count": 1, "min": 15.233516693115234, "max": 15.233516693115234}, "totaltime": {"sum": 1427.3054599761963, "count": 1, "min": 1427.3054599761963, "max": 1427.3054599761963}}}
#
# 2024-04-11 23:02:35 Uploading - Uploading generated training model
# 2024-04-11 23:02:35 Completed - Training job completed
# Training seconds: 287
# Billable seconds: 287

# %% [markdown]
# 7. deploy the model into production and create an endpoint

# %%
knn_predictor = knn_model.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker:Creating model with name: knn-2024-04-11-23-06-05-020
# INFO:sagemaker:Creating endpoint-config with name knn-2024-04-11-23-06-05-020
# INFO:sagemaker:Creating endpoint with name knn-2024-04-11-23-06-05-020
# -------------!

# %%
test_data.iloc[0].tolist()
# Out:
# [0, 38.9, 17.8, 181.0, 3625.0, False, True, False]

# %%
input_data = [38.9, 17.8, 181.0, 3625.0, 0, 1, 0]

# %%
from sagemaker.serializers import CSVSerializer

# %%
knn_predictor.serializer = CSVSerializer()

# %%
knn_predictor.predict(input_data)
# Out:
# b'{"predictions": [{"predicted_label": 0.0}]}'

# %% [markdown]
# 8. delete the model and model endpoint

# %%
knn_predictor.delete_model()
knn_predictor.delete_endpoint() 
knn_predictor.delete_predictor()
# Out:
# INFO:sagemaker:Deleting model with name: knn-2024-04-11-23-06-05-020
# INFO:sagemaker:Deleting endpoint configuration with name: knn-2024-04-11-23-06-05-020
# INFO:sagemaker:Deleting endpoint with name: knn-2024-04-11-23-06-05-020
# INFO:sagemaker:Deleting endpoint configuration with name: knn-2024-04-11-23-06-05-020
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[100], line 3
#       1 knn_predictor.delete_model()
#       2 knn_predictor.delete_endpoint()
# ----> 3 knn_predictor.delete_predictor()
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/base_predictor.py:456, in Predictor.delete_predictor(self, wait)
#     454     self.sagemaker_session.delete_inference_component(self.component_name, wait=wait)
#     455 else:
# --> 456     self.delete_endpoint()
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/base_predictor.py:441, in Predictor.delete_endpoint(self, delete_endpoint_config)
#     429 """Delete the Amazon SageMaker endpoint backing this predictor.
#     430
#     431 This also delete the endpoint configuration attached to it if
#    (...)
#     438         be deleted. If False, only endpoint will be deleted.
#     439 """
#     440 if delete_endpoint_config:
# --> 441     self._delete_endpoint_config()
#     443 self.sagemaker_session.delete_endpoint(self.endpoint_name)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/base_predictor.py:426, in Predictor._delete_endpoint_config(self)
#     424 """Delete the Amazon SageMaker endpoint configuration"""
#     425 current_endpoint_config_name = self._get_endpoint_config_name()
# --> 426 self.sagemaker_session.delete_endpoint_config(current_endpoint_config_name)
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/session.py:4580, in Session.delete_endpoint_config(self, endpoint_config_name)
#    4573 """Delete an Amazon SageMaker endpoint configuration.
#    4574
#    4575 Args:
#    4576     endpoint_config_name (str): Name of the Amazon SageMaker endpoint configuration to
#    4577         delete.
#    4578 """
#    4579 logger.info("Deleting endpoint configuration with name: %s", endpoint_config_name)
# -> 4580 self.sagemaker_client.delete_endpoint_config(EndpointConfigName=endpoint_config_name)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:553, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     549     raise TypeError(
#     550         f"{py_operation_name}() only accepts keyword arguments."
#     551     )
#     552 # The "self" in this scope is referring to the BaseClient.
# --> 553 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:1009, in BaseClient._make_api_call(self, operation_name, api_params)
#    1005     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1006         "Code"
#    1007     )
#    1008     error_class = self.exceptions.from_code(error_code)
# -> 1009     raise error_class(parsed_response, operation_name)
#    1010 else:
#    1011     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DeleteEndpointConfig operation: Could not find endpoint configuration "knn-2024-04-11-23-06-05-020".
